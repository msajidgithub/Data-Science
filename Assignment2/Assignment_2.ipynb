# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sajid\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sajid\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sajid\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sajid\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sajid\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sajid\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Q1. Load the dataset and display first 5 rows?
df = pd.read_csv('dataset.csv')

df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# 0                                  500                    4.5
# 1                                 3000                    3.2
# 2                                  600                    4.8
# 3                                  100                    2.5
# 4                                 2000                    4.3
#
#   Brand of the product  Customer review sentiment score (overall)  \
# 0                 PUMA                                        0.8
# 1                  Lee                                       -0.4
# 2         Head Hunters                                        0.6
# 3    Johnson & Johnson                                        0.1
# 4              Wakefit                                        0.9
#
#    Price of the product Holiday   Season Geographical locations  \
# 0                   200      No   winter                 plains
# 1                   300     Yes  monsoon              mountains
# 2                  1000      No   spring                 plains
# 3                   300      No   summer                coastal
# 4                   700     Yes   winter                 plains
#
#    Probability for the product to be recommended to the person
# 0                                                0.9
# 1                                                0.2
# 2                                                0.7
# 3                                                0.1
# 4                                                0.8

# %%
# Q2. Display dataset shape and column names?
df.shape
# Out:
# (1474, 13)

# %%
# Q3. Check data types of all columns?
df.dtypes
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                          object
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                            object
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                         object
# Season                                                          object
# Geographical locations                                          object
# Probability for the product to be recommended to the person    float64
# dtype: object

# %%
# Q4. Identify missing values in each column?
df.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %%
# Q5. Handle missing values?
df.dropna(inplace=True)
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# 1470                                           13
# 1471                                            8
# 1472                                           15
# 1473                                            4
#
#       Average rating given to similar products  Gender  \
# 0                                          4.2    male
# 1                                          3.8  female
# 2                                          4.5  female
# 3                                          2.1  female
# 4                                          4.7    male
# ...                                        ...     ...
# 1469                                       1.8    male
# 1470                                       4.7  female
# 1471                                       3.9    male
# 1472                                       4.8  female
# 1473                                       3.0    male
#
#       Median purchasing price (in rupees)  Rating of the product  \
# 0                                     500                    4.5
# 1                                    3000                    3.2
# 2                                     600                    4.8
# 3                                     100                    2.5
# 4                                    2000                    4.3
# ...                                   ...                    ...
# 1469                                  200                    2.0
# 1470                                  900                    4.6
# 1471                                 4000                    4.1
# 1472                                  700                    4.9
# 1473                                 5000                    3.2
#
#      Brand of the product  Customer review sentiment score (overall)  \
# 0                    PUMA                                       0.80
# 1                     Lee                                      -0.40
# 2            Head Hunters                                       0.60
# 3       Johnson & Johnson                                       0.10
# 4                 Wakefit                                       0.90
# ...                   ...                                        ...
# 1469        Kama Ayurveda                                      -0.90
# 1470    Johnson & Johnson                                       0.75
# 1471            SleepyCat                                       0.60
# 1472       Flying Machine                                       0.90
# 1473         Head Hunters                                       0.10
#
#       Price of the product Holiday   Season Geographical locations  \
# 0                      200      No   winter                 plains
# 1                      300     Yes  monsoon              mountains
# 2                     1000      No   spring                 plains
# 3                      300      No   summer                coastal
# 4                      700     Yes   winter                 plains
# ...                    ...     ...      ...                    ...
# 1469                   300     Yes   spring                coastal
# 1470                   600      No   summer                 plains
# 1471                   900     Yes   winter              mountains
# 1472                   500      No   summer              mountains
# 1473                   600      No   summer                 plains
#
#       Probability for the product to be recommended to the person
# 0                                                  0.90
# 1                                                  0.20
# 2                                                  0.70
# 3                                                  0.10
# 4                                                  0.80
# ...                                                 ...
# 1469                                               0.01
# 1470                                               0.77
# 1471                                               0.76
# 1472                                               0.82
# 1473                                               0.41
#
# [1474 rows x 13 columns]

# %%
# Q6. Check and remove duplicate rows?
sumOfDuplicates = df.duplicated().sum()
print(sumOfDuplicates)
removeDuplicates = df.drop_duplicates(inplace=True)
print(removeDuplicates)
# Out:
# 456
# None

# %%
# Q7. Generate summary statistics?
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# count                               1018.000000
# mean                                   3.948035
# std                                    0.890671
# min                                    0.000000
# 25%                                    3.425000
# 50%                                    4.200000
# 75%                                    4.700000
# max                                    5.000000
#
#        Median purchasing price (in rupees)  Rating of the product  \
# count                          1018.000000            1018.000000
# mean                           3060.903733               4.011198
# std                            3281.444805               0.892861
# min                             100.000000               0.000000
# 25%                             500.000000               3.400000
# 50%                            1000.000000               4.300000
# 75%                            5500.000000               4.800000
# max                           19000.000000               5.000000
#
#        Customer review sentiment score (overall)  Price of the product  \
# count                                1018.000000           1018.000000
# mean                                    0.411640           1334.921415
# std                                     0.550174           2126.989656
# min                                    -1.000000             90.000000
# 25%                                     0.000000            400.000000
# 50%                                     0.700000            700.000000
# 75%                                     0.850000           1000.000000
# max                                     1.000000          10000.000000
#
#        Probability for the product to be recommended to the person
# count                                        1018.000000
# mean                                            0.656095
# std                                             0.311425
# min                                             0.000000
# 25%                                             0.400000
# 50%                                             0.790000
# 75%                                             0.900000
# max                                             1.000000

# %%
# Q8. Calculate the average of 'Price of the product'?
# df['Price of the product'].mean()
df['Price of the product'].median()
# df['Price of the product'].mode()
# Out:
# 700.0

# %%
# Q9. Find max and min of 'Median purchasing price (in rupees)'?
max_price =  df['Median purchasing price (in rupees)'].max()
min_price = df['Median purchasing price (in rupees)'].min()
print('max price: ', max_price, 'min price: ', min_price)
# Out:
# max price:  19000 min price:  100

# %%
# Q10. Value counts of 'Brand of the product'?
df['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# Fastrack                           22
# The Moms Co.                       22
# Dettol                             21
# Urban Ladder                       20
# SleepyCat                          20
# AmazonBasics                       17
# Allen Solly Woman                  16
# Forest Essentials                  16
# Streax                             15
# Stayfree                           13
# Biovea                             12
# Libram                             12
# Godrej Interio                     12
# Lee Cooper                         11
# Levis Strauss & Co.                11
# Lijoba                             11
# Moov                               11
# Dabur Chyawanprash                 10
# HRX                                 9
# Mothercare                          9
# Duroflex                            9
# Spyker                              8
# Head & Shoulders                    7
# Whisper                             4
# U.S. Polo Assn. Women               4
# Wild Stone                          3
# Dove Hair                           3
# Parachute                           1
# Zandu                               1
# Vero Moda                           1
# Baidyanath                          1
# Name: count, dtype: int64

# %%
# Q11. Sort data by 'Price of the product'?
df.sort_values(by='Price of the product', ascending=False)
# Out:
#       Number of clicks on similar products  \
# 920                                     47
# 1404                                    20
# 1431                                    17
# 851                                     45
# 1444                                    14
# ...                                    ...
# 37                                      18
# 84                                      10
# 764                                     39
# 788                                     34
# 752                                     40
#
#       Number of similar products purchased so far  \
# 920                                            20
# 1404                                            7
# 1431                                            6
# 851                                            18
# 1444                                            5
# ...                                           ...
# 37                                              8
# 84                                              3
# 764                                            15
# 788                                            13
# 752                                            16
#
#       Average rating given to similar products  Gender  \
# 920                                        5.0    male
# 1404                                       4.0  female
# 1431                                       3.8  female
# 851                                        4.8    male
# 1444                                       3.0    male
# ...                                        ...     ...
# 37                                         4.0    male
# 84                                         2.7    male
# 764                                        4.7    male
# 788                                        4.5  female
# 752                                        4.4    male
#
#       Median purchasing price (in rupees)  Rating of the product  \
# 920                                 10000                    4.9
# 1404                                 7000                    4.4
# 1431                                 3000                    3.7
# 851                                  9000                    4.9
# 1444                                 5000                    3.5
# ...                                   ...                    ...
# 37                                    300                    4.2
# 84                                   1000                    2.9
# 764                                   100                    4.6
# 788                                   100                    4.6
# 752                                   100                    4.3
#
#      Brand of the product  Customer review sentiment score (overall)  \
# 920       Himalaya Liv.52                                       0.95
# 1404    Pepe Jeans London                                       0.55
# 1431           Lee Cooper                                       0.35
# 851                Dettol                                       0.90
# 1444         AmazonBasics                                       0.10
# ...                   ...                                        ...
# 37         Lakme Ayurveda                                       0.80
# 84                    Lee                                       0.10
# 764                  Moov                                       0.85
# 788                Dettol                                       0.90
# 752                Biovea                                       0.82
#
#       Price of the product Holiday   Season Geographical locations  \
# 920                  10000     Yes   winter              mountains
# 1404                 10000      No   winter                 plains
# 1431                 10000      No   spring              mountains
# 851                  10000     Yes   winter              mountains
# 1444                 10000      No   spring              mountains
# ...                    ...     ...      ...                    ...
# 37                     100      No   winter                 plains
# 84                     100      No  monsoon                 plains
# 764                     90      No   summer                 plains
# 788                     90      No  monsoon                coastal
# 752                     90      No  monsoon                coastal
#
#       Probability for the product to be recommended to the person
# 920                                                1.00
# 1404                                               0.95
# 1431                                               0.47
# 851                                                0.95
# 1444                                               0.37
# ...                                                 ...
# 37                                                 0.90
# 84                                                 0.10
# 764                                                0.82
# 788                                                0.88
# 752                                                0.75
#
# [1018 rows x 13 columns]

# %%
# Q12. Filter data where rating > 4?

# %%
# Q13. Create new column 'Price Difference'?
# By using (Price of the product - Median Purchasing Price)
df['Price Difference'] = df['Price of the product'] - df['Median purchasing price (in rupees)']
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# 0                                  500                    4.5
# 1                                 3000                    3.2
# 2                                  600                    4.8
# 3                                  100                    2.5
# 4                                 2000                    4.3
#
#   Brand of the product  Customer review sentiment score (overall)  \
# 0                 PUMA                                        0.8
# 1                  Lee                                       -0.4
# 2         Head Hunters                                        0.6
# 3    Johnson & Johnson                                        0.1
# 4              Wakefit                                        0.9
#
#    Price of the product Holiday   Season Geographical locations  \
# 0                   200      No   winter                 plains
# 1                   300     Yes  monsoon              mountains
# 2                  1000      No   spring                 plains
# 3                   300      No   summer                coastal
# 4                   700     Yes   winter                 plains
#
#    Probability for the product to be recommended to the person  \
# 0                                                0.9
# 1                                                0.2
# 2                                                0.7
# 3                                                0.1
# 4                                                0.8
#
#    Price Difference  Price Difference Percentage
# 0              -300                    -0.600000
# 1             -2700                    -0.900000
# 2               400                     0.666667
# 3               200                     2.000000
# 4             -1300                    -0.650000

# %%
# Q14. GroupBy average price by Gender?
df.groupby('Gender')['Price of the product'].median()
# Out:
# Gender
# female    700.0
# male      800.0
# Name: Price of the product, dtype: float64

# %%
# Q15. Create histogram Price of the product?
df['Price of the product'].hist()
plt.show()
