# %%
import sqlite3 as sql
import pandas as pd

# %% [markdown]
# sql.connect('database1.sqlite')

# %%
#connection
conn = sql.connect('database.sqlite')
conn

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_pandas_datetime_CAPI',
#  '_pandas_parser_CAPI',
#  '_testing',
#  '_typing',
#  '_version_meson',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
"select * from sqlite_master"
# Out:
# 'select * from sqlite_master'

# %%
#type table
pd.read_sql_query("select * from sqlite_master", conn) #(query, db connection)
# Out:
#     type               name  tbl_name  rootpage  \
# 0  table           Salaries  Salaries         2
# 1  index  salaries_year_idx  Salaries     16566
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...
# 1  CREATE INDEX salaries_year_idx ON Salaries (Year)

# %%
#table
pd.read_sql_query("select * from sqlite_master where type = 'table'",conn)
# Out:
#     type      name  tbl_name  rootpage  \
# 0  table  Salaries  Salaries         2
#
#                                                  sql
# 0  CREATE TABLE Salaries (\n    Id INTEGER PRIMAR...

# %%
# custom function

# %% [markdown]
# ### table info

# %%
pd.read_sql_query("PRAGMA table_info(Salaries)", conn)
# Out:
#     cid              name     type  notnull dflt_value  pk
# 0     0                Id  INTEGER        0       None   1
# 1     1      EmployeeName     TEXT        0       None   0
# 2     2          JobTitle     TEXT        0       None   0
# 3     3           BasePay  NUMERIC        0       None   0
# 4     4       OvertimePay  NUMERIC        0       None   0
# 5     5          OtherPay  NUMERIC        0       None   0
# 6     6          Benefits  NUMERIC        0       None   0
# 7     7          TotalPay  NUMERIC        0       None   0
# 8     8  TotalPayBenefits  NUMERIC        0       None   0
# 9     9              Year  INTEGER        0       None   0
# 10   10             Notes     TEXT        0       None   0
# 11   11            Agency     TEXT        0       None   0
# 12   12            Status     TEXT        0       None   0

# %%
pd.read_sql_query("PRAGMA table_info(salaries)", conn)
# Out:
#     cid              name     type  notnull dflt_value  pk
# 0     0                Id  INTEGER        0       None   1
# 1     1      EmployeeName     TEXT        0       None   0
# 2     2          JobTitle     TEXT        0       None   0
# 3     3           BasePay  NUMERIC        0       None   0
# 4     4       OvertimePay  NUMERIC        0       None   0
# 5     5          OtherPay  NUMERIC        0       None   0
# 6     6          Benefits  NUMERIC        0       None   0
# 7     7          TotalPay  NUMERIC        0       None   0
# 8     8  TotalPayBenefits  NUMERIC        0       None   0
# 9     9              Year  INTEGER        0       None   0
# 10   10             Notes     TEXT        0       None   0
# 11   11            Agency     TEXT        0       None   0
# 12   12            Status     TEXT        0       None   0

# %%
pd.read_sql_query("select * from Salaries", conn)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ### Null values

# %%
pd.read_sql_query("select * from salaries where employeename is not null" ,conn)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %%
pd.read_sql_query("select * from salaries where employeename is null" ,conn)
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
pd.read_sql_query("select * from salaries where employeename not null" ,conn)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ### distinct

# %%
pd.read_sql_query("select * from salaries",conn)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %%
pd.read_sql_query("select jobtitle from salaries",conn)
# Out:
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# 148651                                    Not provided
# 148652                                    Not provided
# 148653                      Counselor, Log Cabin Ranch
#
# [148654 rows x 1 columns]

# %%
pd.read_sql_query("select jobtitle,employeename,basepay from salaries ",conn)
# Out:
#                                               JobTitle       EmployeeName  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     NATHANIEL FORD
# 1                      CAPTAIN III (POLICE DEPARTMENT)       GARY JIMENEZ
# 2                      CAPTAIN III (POLICE DEPARTMENT)     ALBERT PARDINI
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  CHRISTOPHER CHONG
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)    PATRICK GARDNER
# ...                                                ...                ...
# 148649                                       Custodian      Roy I Tillery
# 148650                                    Not provided       Not provided
# 148651                                    Not provided       Not provided
# 148652                                    Not provided       Not provided
# 148653                      Counselor, Log Cabin Ranch          Joe Lopez
#
#              BasePay
# 0          167411.18
# 1          155966.02
# 2          212739.13
# 3              77916
# 4           134401.6
# ...              ...
# 148649             0
# 148650  Not Provided
# 148651  Not Provided
# 148652  Not Provided
# 148653             0
#
# [148654 rows x 3 columns]

# %%
pd.read_sql_query("select DISTINCT jobtitle from SALARIES" , conn)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %%
pd.read_sql_query("select DISTINCT(jobtitle) from SALARIES" , conn)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %% [markdown]
# ### Alias

# %%
pd.read_sql_query("select employeename from salaries",conn)
# Out:
#              EmployeeName
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %%
pd.read_sql_query("select employeename Employee FROM SALARIES", conn)
# Out:
#                  Employee
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %%
pd.read_sql_query("select employeename Name of Employees FROM SALARIES", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\atiffarooq\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: near "of": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.read_sql_query("select employeename Name of Employees FROM SALARIES", conn)
#
# File c:\Users\atiffarooq\anaconda3\Lib\site-packages\pandas\io\sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File c:\Users\atiffarooq\anaconda3\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File c:\Users\atiffarooq\anaconda3\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'select employeename Name of Employees FROM SALARIES': near "of": syntax error

# %%
pd.read_sql_query("select employeename 'Name of Employees' FROM SALARIES", conn)
# Out:
#         Name of Employees
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %%
pd.read_sql_query("select employeename Name_of_Employees FROM SALARIES", conn)
# Out:
#         Name_of_Employees
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %%
pd.read_sql_query("select employeename as 'Name of Employees' FROM SALARIES", conn)
# Out:
#         Name of Employees
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %%
pd.read_sql_query("select employeename as (Name of Employees) FROM SALARIES", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: near "(": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 pd.read_sql_query("select employeename as (Name of Employees) FROM SALARIES", conn)
#
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'select employeename as (Name of Employees) FROM SALARIES': near "(": syntax error

# %%
pd.read_sql_query("select employeename as '(Name of Employees)' FROM SALARIES", conn)
# Out:
#        (Name of Employees)
# 0           NATHANIEL FORD
# 1             GARY JIMENEZ
# 2           ALBERT PARDINI
# 3        CHRISTOPHER CHONG
# 4          PATRICK GARDNER
# ...                    ...
# 148649       Roy I Tillery
# 148650        Not provided
# 148651        Not provided
# 148652        Not provided
# 148653           Joe Lopez
#
# [148654 rows x 1 columns]

# %%
#function

def sql_query(q):
    return pd.read_sql_query(q,conn)

# %%
q = '''select * froM Salaries'''

sql_query(q)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ### Ascending/Descending order by

# %%
q = '''select basepay,totalpay from salaries'''

sql_query(q)
# Out:
#              BasePay   TotalPay
# 0          167411.18  567595.43
# 1          155966.02  538909.28
# 2          212739.13  335279.91
# 3              77916  332343.61
# 4           134401.6  326373.19
# ...              ...        ...
# 148649             0       0.00
# 148650  Not Provided       0.00
# 148651  Not Provided       0.00
# 148652  Not Provided       0.00
# 148653             0    -618.13
#
# [148654 rows x 2 columns]

# %%
q = '''select basepay,totalpay,otherpay from salaries order by 2'''

sql_query(q)
# Out:
#           BasePay   TotalPay   OtherPay
# 0               0    -618.13    -618.13
# 1               0       0.00          0
# 2               0       0.00          0
# 3               0       0.00          0
# 4               0       0.00          0
# ...           ...        ...        ...
# 148649  128808.87  362844.66   13126.31
# 148650  318835.49  390111.98   60563.54
# 148651  129150.01  471952.64  342802.63
# 148652  155966.02  538909.28  137811.38
# 148653  167411.18  567595.43  400184.25
#
# [148654 rows x 3 columns]

# %%
q = '''select basepay,totalpay,otherpay from salaries order by 2 desc'''

sql_query(q)
# Out:
#              BasePay   TotalPay      OtherPay
# 0          167411.18  567595.43     400184.25
# 1          155966.02  538909.28     137811.38
# 2          129150.01  471952.64     342802.63
# 3          318835.49  390111.98      60563.54
# 4          128808.87  362844.66      13126.31
# ...              ...        ...           ...
# 148649             0       0.00             0
# 148650  Not Provided       0.00  Not Provided
# 148651  Not Provided       0.00  Not Provided
# 148652  Not Provided       0.00  Not Provided
# 148653             0    -618.13       -618.13
#
# [148654 rows x 3 columns]

# %%
q = '''select basepay,totalpay,otherpay from salaries order by totalpay desc'''

sql_query(q)
# Out:
#              BasePay   TotalPay      OtherPay
# 0          167411.18  567595.43     400184.25
# 1          155966.02  538909.28     137811.38
# 2          129150.01  471952.64     342802.63
# 3          318835.49  390111.98      60563.54
# 4          128808.87  362844.66      13126.31
# ...              ...        ...           ...
# 148649             0       0.00             0
# 148650  Not Provided       0.00  Not Provided
# 148651  Not Provided       0.00  Not Provided
# 148652  Not Provided       0.00  Not Provided
# 148653             0    -618.13       -618.13
#
# [148654 rows x 3 columns]

# %%
q = '''select basepay,totalpay,otherpay from salaries order by totalpay asc'''

sql_query(q)

# %%
q = '''select employeename, jobtitle from Salaries where employeename = 'Not Provided'
'''

sql_query(q)
# Out:
#    EmployeeName                                 JobTitle
# 0  Not Provided  PUBLIC SAFETY COMMUNICATIONS DISPATCHER
# 1  Not Provided                   Public SafetyComm Disp

# %%
q = '''select employeename, jobtitle from Salaries where employeename = 'Not provided'
'''

sql_query(q)
# Out:
#    EmployeeName      JobTitle
# 0  Not provided  Not provided
# 1  Not provided  Not provided
# 2  Not provided  Not provided
# 3  Not provided  Not provided

# %%
q = '''select employeename, jobtitle from Salaries where employeename == 'Not Provided'
'''

sql_query(q)
# Out:
#    EmployeeName                                 JobTitle
# 0  Not Provided  PUBLIC SAFETY COMMUNICATIONS DISPATCHER
# 1  Not Provided                   Public SafetyComm Disp

# %% [markdown]
# ### limit

# %%
q = '''select employeename, totalpay from Salaries order by 2 desc limit 10'''

sql_query(q)
# Out:
#            EmployeeName   TotalPay
# 0        NATHANIEL FORD  567595.43
# 1          GARY JIMENEZ  538909.28
# 2           David Shinn  471952.64
# 3            Amy P Hart  390111.98
# 4        Gary Altenberg  362844.66
# 5         John Goldberg  350403.41
# 6           Samson  Lai  347102.32
# 7       Ellen G Moffatt  344187.46
# 8  William J Coaker Jr.  339653.70
# 9        Gregory P Suhr  339282.07

# %%
q = '''select employeename, totalpay from Salaries order by 2 limit 10'''

sql_query(q)
# Out:
#          EmployeeName  TotalPay
# 0           Joe Lopez   -618.13
# 1      PAULETTE ADAMS      0.00
# 2       KAUKAB MOHSIN      0.00
# 3  JOSEPHINE MCCREARY      0.00
# 4       Roland Baylon      0.00
# 5    Felecia Phillips      0.00
# 6     Robert Giannini      0.00
# 7          Nelly Kuan      0.00
# 8     William Mathews      0.00
# 9       Gayle Mathews      0.00

# %%
q = '''select employeename, totalpay from Salaries order by 2
'''


sql_query(q)
# Out:
#               EmployeeName   TotalPay
# 0                Joe Lopez    -618.13
# 1           PAULETTE ADAMS       0.00
# 2            KAUKAB MOHSIN       0.00
# 3       JOSEPHINE MCCREARY       0.00
# 4            Roland Baylon       0.00
# ...                    ...        ...
# 148649      Gary Altenberg  362844.66
# 148650          Amy P Hart  390111.98
# 148651         David Shinn  471952.64
# 148652        GARY JIMENEZ  538909.28
# 148653      NATHANIEL FORD  567595.43
#
# [148654 rows x 2 columns]

# %%
q = '''select employeename, totalpay from Salaries
    where employeename != 'Not provided'
    and 
    employeename != 'Not Provided'
    
'''


sql_query(q)
# Out:
#              EmployeeName   TotalPay
# 0          NATHANIEL FORD  567595.43
# 1            GARY JIMENEZ  538909.28
# 2          ALBERT PARDINI  335279.91
# 3       CHRISTOPHER CHONG  332343.61
# 4         PATRICK GARDNER  326373.19
# ...                   ...        ...
# 148643   Carolyn A Wilson       0.00
# 148644     Joann Anderson       0.00
# 148645        Leon Walker       0.00
# 148646      Roy I Tillery       0.00
# 148647          Joe Lopez    -618.13
#
# [148648 rows x 2 columns]

# %%
q = '''select employeename, totalpay from Salaries
    where employeename != 'Not provided'
    or
    employeename != 'Not Provided'
'''


sql_query(q)
# Out:
#              EmployeeName   TotalPay
# 0          NATHANIEL FORD  567595.43
# 1            GARY JIMENEZ  538909.28
# 2          ALBERT PARDINI  335279.91
# 3       CHRISTOPHER CHONG  332343.61
# 4         PATRICK GARDNER  326373.19
# ...                   ...        ...
# 148649      Roy I Tillery       0.00
# 148650       Not provided       0.00
# 148651       Not provided       0.00
# 148652       Not provided       0.00
# 148653          Joe Lopez    -618.13
#
# [148654 rows x 2 columns]

# %%
q = '''select employeename, totalpay from Salaries
    where employeename != 'Not provided'
    and
    employeename != 'Not Provided'
    order by 2
'''


sql_query(q)
# Out:
#               EmployeeName   TotalPay
# 0                Joe Lopez    -618.13
# 1           PAULETTE ADAMS       0.00
# 2            KAUKAB MOHSIN       0.00
# 3       JOSEPHINE MCCREARY       0.00
# 4            Roland Baylon       0.00
# ...                    ...        ...
# 148643      Gary Altenberg  362844.66
# 148644          Amy P Hart  390111.98
# 148645         David Shinn  471952.64
# 148646        GARY JIMENEZ  538909.28
# 148647      NATHANIEL FORD  567595.43
#
# [148648 rows x 2 columns]

# %% [markdown]
# ### operators

# %% [markdown]
# ### Show jobtitle where overtimepay > 50k and excluded 'not provided' rows

# %%
q = 'select overtimepay from salaries'

sql_query(q)
# Out:
#          OvertimePay
# 0                  0
# 1          245131.88
# 2          106088.18
# 3           56120.71
# 4               9737
# ...              ...
# 148649             0
# 148650  Not Provided
# 148651  Not Provided
# 148652  Not Provided
# 148653             0
#
# [148654 rows x 1 columns]

# %%
q = '''select jobtitle, overtimepay from Salaries
        where overtimepay > 50000
'''

sql_query(q)
# Out:
#                                   JobTitle   OvertimePay
# 0          CAPTAIN III (POLICE DEPARTMENT)     245131.88
# 1          CAPTAIN III (POLICE DEPARTMENT)     106088.18
# 2     WIRE ROPE CABLE MAINTENANCE MECHANIC      56120.71
# 3       BATTALION CHIEF, (FIRE DEPARTMENT)       89062.9
# 4       BATTALION CHIEF, (FIRE DEPARTMENT)      86362.68
# ...                                    ...           ...
# 2164               Parking Control Officer      54738.36
# 2165                          Not provided  Not Provided
# 2166                          Not provided  Not Provided
# 2167                          Not provided  Not Provided
# 2168                          Not provided  Not Provided
#
# [2169 rows x 2 columns]

# %%
q = '''select jobtitle, overtimepay from Salaries
        where overtimepay > 50000
        and
        overtimepay != 'Not Provided'
'''

sql_query(q)
# Out:
#                                   JobTitle  OvertimePay
# 0          CAPTAIN III (POLICE DEPARTMENT)    245131.88
# 1          CAPTAIN III (POLICE DEPARTMENT)    106088.18
# 2     WIRE ROPE CABLE MAINTENANCE MECHANIC     56120.71
# 3       BATTALION CHIEF, (FIRE DEPARTMENT)     89062.90
# 4       BATTALION CHIEF, (FIRE DEPARTMENT)     86362.68
# ...                                    ...          ...
# 2160                      Transit Operator     51625.42
# 2161                      Transit Operator     52550.53
# 2162              Track Maintenance Worker     50265.23
# 2163             Diagnostic Imaging Tech I     74935.96
# 2164               Parking Control Officer     54738.36
#
# [2165 rows x 2 columns]

# %% [markdown]
# ### Show All Employess With A Total Pay Between 50,000 and 75,000

# %%
q = '''select employeename, totalpay from salaries
    where totalpay > 50000 and totalpay < 75000
    '''

sql_query(q)
# Out:
#              EmployeeName  TotalPay
# 0         MAMIKO NAKAMURA  74999.62
# 1           HEDLEY PRINCE  74998.73
# 2           LINDA BARNARD  74998.30
# 3        ANGELA WHITTAKER  74997.84
# 4                JANE CHU  74997.81
# ...                   ...       ...
# 33552     Stephanie Reidy  51785.23
# 33553  Maria Theresa Luna  52266.82
# 33554      Paul E Maltzer  51673.98
# 33555       Kevin I Dolar  50953.19
# 33556   Kathleen N Yumang  50348.91
#
# [33557 rows x 2 columns]

# %%
# Show All Employess With A Total Pay Between 50,000 and 75,000

q = '''select employeename, totalpay from salaries
    where totalpay between 50000 and 75000'''

sql_query(q)
# Out:
#              EmployeeName  TotalPay
# 0         MAMIKO NAKAMURA  74999.62
# 1           HEDLEY PRINCE  74998.73
# 2           LINDA BARNARD  74998.30
# 3        ANGELA WHITTAKER  74997.84
# 4                JANE CHU  74997.81
# ...                   ...       ...
# 33552     Stephanie Reidy  51785.23
# 33553  Maria Theresa Luna  52266.82
# 33554      Paul E Maltzer  51673.98
# 33555       Kevin I Dolar  50953.19
# 33556   Kathleen N Yumang  50348.91
#
# [33557 rows x 2 columns]

# %% [markdown]
# ### Show All Employees With A BasePay less than 50,000 Or A TotalPay Greater Than 100,000

# %%
q = '''select employeename, basepay, totalpay from Salaries
    where basepay < 50000 
    or
    totalpay > 100000
    order by 3 desc
    limit 10'''

sql_query(q)
# Out:
#            EmployeeName    BasePay   TotalPay
# 0        NATHANIEL FORD  167411.18  567595.43
# 1          GARY JIMENEZ  155966.02  538909.28
# 2           David Shinn  129150.01  471952.64
# 3            Amy P Hart  318835.49  390111.98
# 4        Gary Altenberg  128808.87  362844.66
# 5         John Goldberg  104404.00  350403.41
# 6           Samson  Lai  186236.42  347102.32
# 7       Ellen G Moffatt  270222.04  344187.46
# 8  William J Coaker Jr.  257340.00  339653.70
# 9        Gregory P Suhr  319275.01  339282.07

# %% [markdown]
# ### Aggregate functions

# %%
q = '''select count(*) "captain count" from salaries where jobtitle = 'CAPTAIN III (POLICE DEPARTMENT)'
'''

sql_query(q)
# Out:
#    captain count
# 0             37

# %%
q = '''select count(jobtitle) from salaries where jobtitle = 'CAPTAIN III (POLICE DEPARTMENT)'
'''

sql_query(q)
# Out:
#    count(jobtitle)
# 0               37

# %%
q = "select distinct(jobtitle) from salaries"

sql_query(q)
# Out:
#                                             JobTitle
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %%
q = '''select count(jobtitle) 'Captain Count' from salaries where jobtitle = 'CAPTAIN III (POLICE DEPARTMENT)'
'''

sql_query(q)
# Out:
#    Captain Count
# 0             37

# %%
#average

q = '''select avg(totalpay) 'avergae TP of Custodian' from Salaries where jobtitle = 'Custodian'
'''

sql_query(q)
# Out:
#    avergae TP of Custodian
# 0             47070.542419

# %%
#max 

q = '''select max(totalpay) as max_number from Salaries'''

sql_query(q)
# Out:
#    max_number
# 0   567595.43

# %%
#max 

q = '''select max(totalpay), employeename from Salaries'''

sql_query(q)
# Out:
#    max(totalpay)    EmployeeName
# 0      567595.43  NATHANIEL FORD

# %%
#max 

q = '''select max(totalpay), employeename, jobtitle from Salaries'''


sql_query(q)
# Out:
#    max(totalpay)    EmployeeName  \
# 0      567595.43  NATHANIEL FORD
#
#                                          JobTitle
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY

# %%
# How many employees in the salaries table have OvertimePay equal to 0?
q = '''select count(employeename) from salaries where overtimepay = 0
'''

sql_query(q)
# Out:
#    count(employeename)
# 0                77321

# %%
# How many employees in the salaries table have OvertimePay equal to 0?
q = '''select * from salaries where overtimepay = 0
'''

sql_query(q)
# Out:
#            Id        EmployeeName  \
# 0           1      NATHANIEL FORD
# 1           8       DAVID KUSHNER
# 2          10  JOANNE HAYES-WHITE
# 3          13   EDWARD HARRINGTON
# 4          14         JOHN MARTIN
# ...       ...                 ...
# 77316  148646    Carolyn A Wilson
# 77317  148648      Joann Anderson
# 77318  148649         Leon Walker
# 77319  148650       Roy I Tillery
# 77320  148654           Joe Lopez
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18            0
# 1                      DEPUTY DIRECTOR OF INVESTMENTS  256576.96            0
# 2              CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)     285262            0
# 3                         EXECUTIVE CONTRACT EMPLOYEE  294580.02            0
# 4                                   DEPARTMENT HEAD V  271329.03            0
# ...                                               ...        ...          ...
# 77316                       Human Services Technician          0            0
# 77317                     Communications Dispatcher 2          0            0
# 77318                                       Custodian          0            0
# 77319                                       Custodian          0            0
# 77320                      Counselor, Log Cabin Ranch          0            0
#
#         OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0      400184.25           567595.43         567595.43  2011
# 1       51322.50           307899.46         307899.46  2011
# 2       17115.73           302377.73         302377.73  2011
# 3           0.00           294580.02         294580.02  2011
# 4       21342.59           292671.62         292671.62  2011
# ...          ...      ...        ...               ...   ...   ...
# 77316       0.00        0       0.00              0.00  2014
# 77317       0.00        0       0.00              0.00  2014
# 77318       0.00        0       0.00              0.00  2014
# 77319       0.00        0       0.00              0.00  2014
# 77320    -618.13        0    -618.13           -618.13  2014
#
#               Agency Status
# 0      San Francisco
# 1      San Francisco
# 2      San Francisco
# 3      San Francisco
# 4      San Francisco
# ...              ...    ...
# 77316  San Francisco     PT
# 77317  San Francisco     PT
# 77318  San Francisco     PT
# 77319  San Francisco     PT
# 77320  San Francisco     PT
#
# [77321 rows x 13 columns]

# %%
# How many employees in the salaries table have OvertimePay equal to 0?
q = '''select count(*) from salaries where overtimepay = 0
'''

sql_query(q)
# Out:
#    count(*)
# 0     77321

# %%
q = '''select * from salaries where jobtitle = 'CAPTAIN III (POLICE DEPARTMENT)'
'''
sql_query(q)
# Out:
#        Id       EmployeeName                         JobTitle    BasePay  \
# 0       2       GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 1       3     ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 2      12   PATRICIA JACKSON  CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 3      62         ANNA BROWN  CAPTAIN III (POLICE DEPARTMENT)  102571.24
# 4      66      RICHARD PARRY  CAPTAIN III (POLICE DEPARTMENT)  185369.69
# 5      92      DONNA MEIXNER  CAPTAIN III (POLICE DEPARTMENT)  102722.40
# 6      94        JOHN MURPHY  CAPTAIN III (POLICE DEPARTMENT)  215914.03
# 7     126    SHARON FERRIGNO  CAPTAIN III (POLICE DEPARTMENT)  185369.68
# 8     212     CROCE CASCIATO  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 9     215        JOHN FEENEY  CAPTAIN III (POLICE DEPARTMENT)  188348.55
# 10    226   STEPHEN TACCHINI  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# 11    240   GREGORY CORRALES  CAPTAIN III (POLICE DEPARTMENT)  188341.64
# 12    241       JOHN EHRLICH  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 13    249     DANIEL MAHONEY  CAPTAIN III (POLICE DEPARTMENT)  196061.30
# 14    253      JOHN GOLDBERG  CAPTAIN III (POLICE DEPARTMENT)  188341.61
# 15    254      ANTONIO PARRA  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# 16    258      KEITH SANFORD  CAPTAIN III (POLICE DEPARTMENT)  188341.84
# 17    262      PAUL CHIGNELL  CAPTAIN III (POLICE DEPARTMENT)  188314.54
# 18    275       DENIS OLEARY  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# 19    278    LOUIS CASSANEGO  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# 20    285         GARRET TOM  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 21    297        DAVID LAZAR  CAPTAIN III (POLICE DEPARTMENT)  195975.32
# 22    304  DOUGLAS MCEACHERN  CAPTAIN III (POLICE DEPARTMENT)  194566.01
# 23    320         ANN MANNIX  CAPTAIN III (POLICE DEPARTMENT)  188314.50
# 24    349       JOHN GARRITY  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 25    367        JOHN LOFTUS  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 26    368     DOMINIC CELAYA  CAPTAIN III (POLICE DEPARTMENT)  188341.64
# 27    369    JOHN SANFORD JR  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# 28    370     STEPHEN TITTEL  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# 29    371     TERESA BARRETT  CAPTAIN III (POLICE DEPARTMENT)  188328.08
# 30    372      VALERIE AGARD  CAPTAIN III (POLICE DEPARTMENT)  185342.48
# 31    397      CHARLIE ORKES  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# 32    426   MICHAEL CONNOLLY  CAPTAIN III (POLICE DEPARTMENT)  188341.63
# 33    526         CURTIS LUM  CAPTAIN III (POLICE DEPARTMENT)  184700.97
# 34    913      SYLVIA HARPER  CAPTAIN III (POLICE DEPARTMENT)   71230.00
# 35   4144    ANTHONY FOTINOS  CAPTAIN III (POLICE DEPARTMENT)   42738.00
# 36  11199      KATHRYN BROWN  CAPTAIN III (POLICE DEPARTMENT)   10684.50
#
#     OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  Year Notes  \
# 0     245131.88  137811.38           538909.28         538909.28  2011
# 1     106088.18   16452.60           335279.91         335279.91  2011
# 2      87082.62  110804.30           297608.92         297608.92  2011
# 3       7437.00  128543.64           238551.88         238551.88  2011
# 4      37873.61   14465.53           237708.83         237708.83  2011
# 5       7437.00  118456.21           228615.61         228615.61  2011
# 6          0.00   12293.83           228207.86         228207.86  2011
# 7      27321.83    4651.44           217342.95         217342.95  2011
# 8          0.00   16206.24           204547.86         204547.86  2011
# 9       5720.22   10173.43           204242.20         204242.20  2011
# 10      2258.63   12252.44           202852.67         202852.67  2011
# 11      1109.10   12252.70           201703.44         201703.44  2011
# 12      1068.45   12211.62           201621.69         201621.69  2011
# 13         0.00    4749.91           200811.21         200811.21  2011
# 14         0.00   12119.40           200461.01         200461.01  2011
# 15         0.00   12119.37           200460.97         200460.97  2011
# 16      1134.34   10799.25           200275.43         200275.43  2011
# 17         0.00   11547.94           199862.48         199862.48  2011
# 18         0.00   10542.72           198884.32         198884.32  2011
# 19         0.00   10125.04           198466.64         198466.64  2011
# 20      2886.03    6646.21           197873.86         197873.86  2011
# 21         0.00     917.32           196892.64         196892.64  2011
# 22      1109.10     819.03           196494.14         196494.14  2011
# 23         0.00    7310.63           195625.13         195625.13  2011
# 24      1131.28    4586.65           194059.55         194059.55  2011
# 25         0.00    4609.75           192951.37         192951.37  2011
# 26         0.00    4586.67           192928.31         192928.31  2011
# 27         0.00    4586.66           192928.28         192928.28  2011
# 28         0.00    4586.63           192928.23         192928.23  2011
# 29         0.00    4586.42           192914.50         192914.50  2011
# 30      3627.67    3936.60           192906.75         192906.75  2011
# 31      1109.10    1954.26           191404.96         191404.96  2011
# 32         0.00     915.59           189257.22         189257.22  2011
# 33         0.00     851.04           185552.01         185552.01  2011
# 34         0.00  101242.15           172472.15         172472.15  2011
# 35     47827.70   39904.72           130470.42         130470.42  2011
# 36         0.00   81244.87            91929.37          91929.37  2011
#
#            Agency Status
# 0   San Francisco
# 1   San Francisco
# 2   San Francisco
# 3   San Francisco
# 4   San Francisco
# 5   San Francisco
# 6   San Francisco
# 7   San Francisco
# 8   San Francisco
# 9   San Francisco
# 10  San Francisco
# 11  San Francisco
# 12  San Francisco
# 13  San Francisco
# 14  San Francisco
# 15  San Francisco
# 16  San Francisco
# 17  San Francisco
# 18  San Francisco
# 19  San Francisco
# 20  San Francisco
# 21  San Francisco
# 22  San Francisco
# 23  San Francisco
# 24  San Francisco
# 25  San Francisco
# 26  San Francisco
# 27  San Francisco
# 28  San Francisco
# 29  San Francisco
# 30  San Francisco
# 31  San Francisco
# 32  San Francisco
# 33  San Francisco
# 34  San Francisco
# 35  San Francisco
# 36  San Francisco

# %%
q = '''select sum(overtimepay) from salaries where jobtitle = 'CAPTAIN III (POLICE DEPARTMENT)'
'''
sql_query(q)
# Out:
#    sum(overtimepay)
# 0         587353.74

# %% [markdown]
# ### GROUP BY --- HAVING
#
# GROUP BY works after the WHERE clause filters the rows and before the HAVING clause filters the groups.

# %% [markdown]
# - Count Employees by JobTitle
# - Average TotalPay by JobTitle
# - Employees with the Highest TotalPay in Each Year
# - Sum of TotalPay by Year and JobTitle
# - Employees with TotalPay Greater Than 1,000,000 by JobTitle
# - Employees with Average BasePay Greater Than 50,000 by JobTitle
# - Employee Count Greater Than 10 in Each Year
# - Job Titles with More Than 5 Employees and Average TotalPay Greater Than 100,000

# %%
#Count Employees by JobTitle

q = '''select count(employeename) 'count of employeename', jobtitle from salaries
    group by 2
    '''

sql_query(q)
# Out:
#       count of employeename                                        JobTitle
# 0                        83                                   ACCOUNT CLERK
# 1                         5                                      ACCOUNTANT
# 2                        48                               ACCOUNTANT INTERN
# 3                         1                     ACPO,JuvP, Juv Prob (SFERS)
# 4                         1                                   ACUPUNCTURIST
# ...                     ...                                             ...
# 2154                     26                           X-RAY LABORATORY AIDE
# 2155                    100                           X-Ray Laboratory Aide
# 2156                      1  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS
# 2157                      4                              Youth Comm Advisor
# 2158                      1                                     ZOO CURATOR
#
# [2159 rows x 2 columns]

# %%
# Average TotalPay by JobTitle

q = '''select jobtitle, avg(totalpay) as AverageOfTotalPay from salaries
group by jobtitle
'''

sql_query(q)
# Out:
#                                             JobTitle  AverageOfTotalPay
# 0                                      ACCOUNT CLERK       44035.664337
# 1                                         ACCOUNTANT       47429.268000
# 2                                  ACCOUNTANT INTERN       29031.742917
# 3                        ACPO,JuvP, Juv Prob (SFERS)       62290.780000
# 4                                      ACUPUNCTURIST       67594.400000
# ...                                              ...                ...
# 2154                           X-RAY LABORATORY AIDE       52705.880385
# 2155                           X-Ray Laboratory Aide       50823.942700
# 2156  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS       53632.870000
# 2157                              Youth Comm Advisor       41414.307500
# 2158                                     ZOO CURATOR       66686.560000
#
# [2159 rows x 2 columns]

# %%
# Average TotalPay by JobTitle

q = '''select jobtitle, avg(totalpay) as AverageOfTotalPay from salaries
group by jobtitle
order by 2 desc
limit 10
'''

sql_query(q)
# Out:
#                                          JobTitle  AverageOfTotalPay
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY      399211.275000
# 1                        Chief Investment Officer      339653.700000
# 2                                 Chief of Police      329183.646667
# 3                          Chief, Fire Department      325971.683333
# 4                  DEPUTY DIRECTOR OF INVESTMENTS      307899.460000
# 5          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)      302377.730000
# 6                      Gen Mgr, Public Trnsp Dept      297769.413333
# 7                    Asst Chf of Dept (Fire Dept)      281763.483889
# 8    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      279359.560000
# 9                    Dep Dir for Investments, Ret      278592.545000

# %%
a = pd.read_sql_query(q, conn)
a
# Out:
#                                          JobTitle  AverageOfTotalPay
# 0  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY      399211.275000
# 1                        Chief Investment Officer      339653.700000
# 2                                 Chief of Police      329183.646667
# 3                          Chief, Fire Department      325971.683333
# 4                  DEPUTY DIRECTOR OF INVESTMENTS      307899.460000
# 5          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)      302377.730000
# 6                      Gen Mgr, Public Trnsp Dept      297769.413333
# 7                    Asst Chf of Dept (Fire Dept)      281763.483889
# 8    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      279359.560000
# 9                    Dep Dir for Investments, Ret      278592.545000

# %%
import matplotlib.pyplot as plt

# %%
a = pd.read_sql_query(q, conn)
a.plot(kind='barh', x='JobTitle', y='AverageOfTotalPay', color='skyblue', figsize=(10, 6))

plt.xlabel('Jobtitle')
plt.ylabel('Average of totalpay')
plt.title('Top 10 Job Titles by Number of Employees')

plt.show()

# %%
a = pd.read_sql_query(q, conn)
a.plot(kind='bar', x='JobTitle', y='AverageOfTotalPay', color='red', figsize=(10, 6))

plt.xlabel('Jobtitle')
plt.ylabel('Average of totalpay')
plt.title('Top 10 Job Titles by Number of Employees')

plt.show()

# %%
# Employees with TotalPay Greater Than 1,000,000 by JobTitle

q = '''select count(employeename) 'count of employeename', jobtitle, totalpay from salaries
    group by 2
    where totalpay > 10000
    '''

sql_query(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: near "where": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[87], line 8
#       1 # Employees with TotalPay Greater Than 1,000,000 by JobTitle
#       3 q = '''select count(employeename) 'count of employeename', jobtitle, totalpay from salaries
#       4     group by 2
#       5     where totalpay > 10000
#       6     '''
# ----> 8 sql_query(q)
#
# Cell In[32], line 4, in sql_query(q)
#       3 def sql_query(q):
# ----> 4     return pd.read_sql_query(q,conn)
#
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File D:\Anaconda\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'select count(employeename) 'count of employeename', jobtitle, totalpay from salaries
#     group by 2
#     where totalpay > 10000
#     ': near "where": syntax error

# %%
# Employees with TotalPay Greater Than 1,000,000 by JobTitle

q = '''select count(employeename) 'count of employeename', jobtitle, totalpay from salaries
    group by 2
    having totalpay > 10000
    '''

sql_query(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       1 # Employees with TotalPay Greater Than 1,000,000 by JobTitle
#       3 q = '''select count(employeename) 'count of employeename', jobtitle, totalpay from salaries
#       4     group by 2
#       5     having totalpay > 10000
#       6     '''
# ----> 8 sql_query(q)
#
# NameError: name 'sql_query' is not defined

# %%
import sqlite3 as sql
import pandas as pd


conn = sql.connect('database.sqlite')
conn

# Employee count greater than 10 in each year

# q = '''
# SELECT Year, COUNT(*) AS Employee_Count
# FROM salaries
# GROUP BY Year
# HAVING COUNT(*) > 10
# '''
# sql_query(q)

# %%
# Job titles with more than 5 employees and average TotalPay greater than 100k

q = '''
SELECT JobTitle,
       COUNT(*) AS EmployeeCount,
       AVG(TotalPay) AS Average_TotalPay
FROM salaries
GROUP BY JobTitle
HAVING COUNT(*) > 5
   AND AVG(TotalPay) > 100000
'''
sql_query(q)

# %%
# Employees with average BasePay greater than 50k by JobTitle

q = '''
SELECT JobTitle, AVG(BasePay) AS "Average BasePay"
FROM salaries
GROUP BY JobTitle
HAVING AVG(BasePay) > 50000
'''
sql_query(q)
