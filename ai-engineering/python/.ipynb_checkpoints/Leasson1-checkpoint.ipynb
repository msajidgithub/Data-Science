# %%
name = 'Sajid'
city = 'karachi'
age = 30
experience = 4
status = True
print(type(name))
print(type(age))
print(type(city))
print(type(status))
print(type(experience))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
age = 23 
if age > 18:
    print('you can vote')
else:
    print('you can not vote')
# Out:
# you can vote

# %%
marks = 66
if marks >= 80:
    print('A')
elif marks >= 60:
    print('B')
elif marks >= 40:
    print('C')
else:
print('Fail')
# Out:
#   Cell In[5], line 6
#     elif marks >= 40:
#     ^
# SyntaxError: invalid syntax
